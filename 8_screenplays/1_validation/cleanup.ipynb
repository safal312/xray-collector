# %% [markdown]
# ### Cleanup metadata

# %% [markdown]
# This notebook transforms the data after validation. It also removes duplicates and picks the best screenplay among them.

# %%
import pandas as pd
import os

# %%
METADATA_DIR = "../../data/8_screenplays/1_validation"
# read metadata before validation
bfr_valid = pd.read_csv(f'{METADATA_DIR}/validation.csv', dtype={'imdb_id': str, 'alt_id': str})

# %%
aftr_valid = pd.read_csv(f'{METADATA_DIR}/validated_file.csv', header=None, dtype={0: str, 3: str})

# %%
bfr_valid.head()
# Out:
#    imdb_id                       title                    filename  match  \
# 0  0147800  10 Things I Hate About You  10-Things-I-Hate-About-You      0
# 1  0417385              12 and Holding              12-and-Holding      0
# 2  3148266                  12 Monkeys                  12-Monkeys      0
# 3  2024544            12 Years a Slave            12-Years-a-Slave      0
# 4  1542344                   127 Hours                   127-Hours      0
#
#     alt_id                                         script_url  notes
# 0  0147800  https://imsdb.com/scripts/10-Things-I-Hate-Abo...    NaN
# 1  0417385      https://imsdb.com/scripts/12-and-Holding.html    NaN
# 2  3148266          https://imsdb.com/scripts/12-Monkeys.html    NaN
# 3  2024544    https://imsdb.com/scripts/12-Years-a-Slave.html    NaN
# 4  1542344           https://imsdb.com/scripts/127-Hours.html    NaN

# %%
aftr_valid.columns = ['imdb_id', 'title', 'match', 'alt_id', 'script_url', 'notes']

# %%
aftr_valid.shape, bfr_valid.shape
# Out:
# ((1653, 6), (1653, 7))

# %%
aftr_valid['filename'] = bfr_valid['filename']

# %%
aftr_valid.head()
# Out:
#    imdb_id                       title  match   alt_id  \
# 0  0147800  10 Things I Hate About You      1      NaN
# 1  0417385              12 and Holding      1      NaN
# 2  3148266                  12 Monkeys      0  0114746
# 3  2024544            12 Years a Slave      1      NaN
# 4  1542344                   127 Hours      1      NaN
#
#                                           script_url                notes  \
# 0  https://imsdb.com/scripts/10-Things-I-Hate-Abo...                  NaN
# 1      https://imsdb.com/scripts/12-and-Holding.html                  NaN
# 2          https://imsdb.com/scripts/12-Monkeys.html  Given id is tv show
# 3    https://imsdb.com/scripts/12-Years-a-Slave.html                  NaN
# 4           https://imsdb.com/scripts/127-Hours.html                  NaN
#
#                      filename
# 0  10-Things-I-Hate-About-You
# 1              12-and-Holding
# 2                  12-Monkeys
# 3            12-Years-a-Slave
# 4                   127-Hours

# %%
aftr_valid['id_merged'] = aftr_valid['alt_id'].fillna(aftr_valid['imdb_id'])

# %%
aftr_valid.head()
# Out:
#    imdb_id                       title  match   alt_id  \
# 0  0147800  10 Things I Hate About You      1      NaN
# 1  0417385              12 and Holding      1      NaN
# 2  3148266                  12 Monkeys      0  0114746
# 3  2024544            12 Years a Slave      1      NaN
# 4  1542344                   127 Hours      1      NaN
#
#                                           script_url                notes  \
# 0  https://imsdb.com/scripts/10-Things-I-Hate-Abo...                  NaN
# 1      https://imsdb.com/scripts/12-and-Holding.html                  NaN
# 2          https://imsdb.com/scripts/12-Monkeys.html  Given id is tv show
# 3    https://imsdb.com/scripts/12-Years-a-Slave.html                  NaN
# 4           https://imsdb.com/scripts/127-Hours.html                  NaN
#
#                      filename id_merged
# 0  10-Things-I-Hate-About-You   0147800
# 1              12-and-Holding   0417385
# 2                  12-Monkeys   0114746
# 3            12-Years-a-Slave   2024544
# 4                   127-Hours   1542344

# %% [markdown]
# We have to remove scripts for which we couldn't find alternate ids. Like unproduced scripts.

# %%
clean_1 = aftr_valid[~((aftr_valid['match'] == 0) & (aftr_valid['alt_id'].isnull()))]

# %%
clean_1.shape
# Out:
# (1614, 8)

# %% [markdown]
# Now, we'll look into duplicates.

# %% [markdown]
# Duplicates could arise from having the same script from multiple sources. Also, if initial matching was wrong and two same scripts were identified as different, now, they'll be duplicates after the validation.

# %%
dups = clean_1[clean_1['id_merged'].duplicated()]

# %% [markdown]
# To choose between the duplicates, we'll see the characters info that was parsed with the script.

# %%
clean_1['char_fname'] = clean_1['filename'] + '_charinfo.txt'
# Out:
# C:\Users\safal\AppData\Local\Temp\ipykernel_15548\2568025173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_1['char_fname'] = clean_1['filename'] + '_charinfo.txt'

# %%
BASE_DIR = '../../data/8_screenplays/parsed_screenplays/parsed/'
movie_chars = os.listdir(os.path.join(BASE_DIR, 'charinfo'))
rows = []

for item in movie_chars:
  fname = item
  if len(clean_1.loc[clean_1['char_fname'] == item, 'imdb_id']) == 0: continue
  imdb = clean_1.loc[clean_1['char_fname'] == item, 'imdb_id'].values[0]
  alt_id = clean_1.loc[clean_1['char_fname'] == item, 'id_merged'].values[0]

  file_path = os.path.join(BASE_DIR, 'charinfo', item)
  with open(file_path, 'r', encoding='utf-8') as f:
    data = f.read()
    if data == '': print(file_path, data)
    for line in data.split('\n'):
      if line == '': continue
      item = {}
      # char = re.split(":(?= [\d]+)", line)
      index = line.rfind(":")
      # print(char)
      item['imdb'] = imdb
      item['alt_id'] = alt_id
      item['char'] = line[:index].strip()
      item['utterances'] = line[index+1:].strip()
      item['fname'] = fname

      rows.append(item)
# Out:
# ../../data/8_screenplays/parsed_screenplays/parsed/charinfo\Nightbreed_charinfo.txt
# ../../data/8_screenplays/parsed_screenplays/parsed/charinfo\Sexual-Life_charinfo.txt
# ../../data/8_screenplays/parsed_screenplays/parsed/charinfo\Space-Ball_charinfo.txt
# ../../data/8_screenplays/parsed_screenplays/parsed/charinfo\Spaceballs_charinfo.txt

# %%
df_temp = pd.DataFrame(rows)
df_temp['utterances'] = pd.to_numeric(df_temp['utterances'], errors='coerce')

# %%
df_temp.shape
# Out:
# (86436, 5)

# %%
df_temp.head()
# Out:
#       imdb   alt_id               char  utterances  \
# 0  0147800  0147800          BARTENDER           2
# 1  0147800  0147800             BIANCA         131
# 2  0147800  0147800  BIANCA AND WALTER           1
# 3  0147800  0147800              BOGEY           1
# 4  0147800  0147800                BOY           2
#
#                                      fname
# 0  10-Things-I-Hate-About-You_charinfo.txt
# 1  10-Things-I-Hate-About-You_charinfo.txt
# 2  10-Things-I-Hate-About-You_charinfo.txt
# 3  10-Things-I-Hate-About-You_charinfo.txt
# 4  10-Things-I-Hate-About-You_charinfo.txt

# %% [markdown]
# Now, we'll check for matching between two duplicate scripts.

# %%
df_selected = pd.DataFrame()

for index, row in dups.iterrows():
  id = row['id_merged']

  movies = clean_1.loc[clean_1['id_merged'] == id]
  max = -1
  maxfile = ""

  for each in movies['filename']:
    fname = each + '_charinfo.txt'

    chars = df_temp.loc[df_temp['fname'] == fname]

    # we choose the duplicate that has the most characters as a metric
    if len(chars['char']) > max:
      max = len(chars['char'])
      maxfile = each

  df_selected = pd.concat([df_selected, movies.loc[movies['filename'] == maxfile]])
  # print(maxfile, max)

# %% [markdown]
# If there were more than one duplicates in dups dataframe for a particular movie, we'll compare among the duplicates each time we encounter it. Therefore, we'll have to again remove duplicates from the resulting dataframe as we may have compared the same movie multiple times. Example, 8MM has 3 scripts. 2 of them are in the dups file. Each time we encounter the duplicate in dups, we'll compare and select one among the three scripts, resulting in 2 selections.

# %%
df_selected[df_selected['id_merged'].duplicated()]
# Out:
#       imdb_id                title  match   alt_id  \
# 17    0134273                  8MM      1      NaN
# 931   0053559            13 Ghosts      0  0245674
# 1136  0111686        New Nightmare      1      NaN
# 564   0070379         Mean Streets      1      NaN
# 170   0112573           Braveheart      1      NaN
# 354   0104348  Glengarry Glen Ross      1      NaN
#
#                                              script_url  \
# 17                   https://imsdb.com/scripts/8MM.html
# 931   https://www.dailyscript.com/scripts/thirteen_g...
# 1136  https://www.dailyscript.com/scripts/WesCravens...
# 564         https://imsdb.com/scripts/Mean-Streets.html
# 170           https://imsdb.com/scripts/Braveheart.html
# 354   https://imsdb.com/scripts/Glengarry-Glen-Gross...
#
#                       notes              filename id_merged  \
# 17                      NaN                   8MM   0134273
# 931   Older movie preferred             13-Ghosts   0245674
# 1136                    NaN         New-Nightmare   0111686
# 564                     NaN          Mean-Streets   0070379
# 170                     NaN            Braveheart   0112573
# 354                     NaN  Glengarry-Glen-Gross   0104348
#
#                              char_fname
# 17                     8MM_charinfo.txt
# 931              13-Ghosts_charinfo.txt
# 1136         New-Nightmare_charinfo.txt
# 564           Mean-Streets_charinfo.txt
# 170             Braveheart_charinfo.txt
# 354   Glengarry-Glen-Gross_charinfo.txt

# %% [markdown]
# Now, we'll first remove all duplicates, then add back the selected ones among the duplicates.

# %%
clean_2 = clean_1.drop_duplicates(subset=['id_merged'], keep=False)

# %%
clean_2.shape
# Out:
# (1380, 9)

# %%
df_selected_clean = df_selected.drop_duplicates(subset=['id_merged'])

# %%
clean_2 = pd.concat([clean_2, df_selected_clean])

# %%
clean_2
# Out:
#       imdb_id                        title  match   alt_id  \
# 1     0417385               12 and Holding      1      NaN
# 3     2024544             12 Years a Slave      1      NaN
# 4     1542344                    127 Hours      1      NaN
# 6     0179626                   15 Minutes      1      NaN
# 7     0974661                     17 Again      1      NaN
# ...       ...                          ...    ...      ...
# 1287  0073802     Three Days of the Condor      1      NaN
# 932   4385888           20th Century Women      1      NaN
# 1035  4882376  First They Killed My Father      1      NaN
# 1566  7440732         The Kids Are Alright      0  0842926
# 1616  1340800    Tinker Tailor Soldier Spy      1      NaN
#
#                                              script_url  \
# 1         https://imsdb.com/scripts/12-and-Holding.html
# 3       https://imsdb.com/scripts/12-Years-a-Slave.html
# 4              https://imsdb.com/scripts/127-Hours.html
# 6             https://imsdb.com/scripts/15-Minutes.html
# 7               https://imsdb.com/scripts/17-Again.html
# ...                                                 ...
# 1287  http://www.awesomefilm.com/script/ThreeDaysoft...
# 932   https://www.dailyscript.com/scripts/20TH_CENTU...
# 1035      https://www.dailyscript.com/scripts/FTKMF.pdf
# 1566  https://s3-us-west-2.amazonaws.com/screenplays...
# 1616  https://s3-us-west-2.amazonaws.com/screenplays...
#
#                         notes                            filename id_merged  \
# 1                         NaN                      12-and-Holding   0417385
# 3                         NaN                    12-Years-a-Slave   2024544
# 4                         NaN                           127-Hours   1542344
# 6                         NaN                          15-Minutes   0179626
# 7                         NaN                            17-Again   0974661
# ...                       ...                                 ...       ...
# 1287                      NaN             Three-Days-of-the-Condo   0073802
# 932                       NaN                  20th-Century-Woman   4385888
# 1035                      NaN  FTKMF-(First-They-Killed-My-Father   4882376
# 1566  Newer tv show preferred                Kids-Are-Alright-The   0842926
# 1616                      NaN           Tinker-Tailor-Solider-Spy   1340800
#
#                                            char_fname
# 1                         12-and-Holding_charinfo.txt
# 3                       12-Years-a-Slave_charinfo.txt
# 4                              127-Hours_charinfo.txt
# 6                             15-Minutes_charinfo.txt
# 7                               17-Again_charinfo.txt
# ...                                               ...
# 1287             Three-Days-of-the-Condo_charinfo.txt
# 932                   20th-Century-Woman_charinfo.txt
# 1035  FTKMF-(First-They-Killed-My-Father_charinfo.txt
# 1566                Kids-Are-Alright-The_charinfo.txt
# 1616           Tinker-Tailor-Solider-Spy_charinfo.txt
#
# [1494 rows x 9 columns]

# %%
clean_2[clean_2['id_merged'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [imdb_id, title, match, alt_id, script_url, notes, filename, id_merged, char_fname]
# Index: []

# %%
clean_2.to_csv(f'{METADATA_DIR}/clean_validated.csv', index=False)
