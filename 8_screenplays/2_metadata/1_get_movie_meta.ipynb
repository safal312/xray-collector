# %% [markdown]
# ### Get Movie Metadata

# %% [markdown]
# This notebook gathers metadata from IMDb which includes crew information, description, year, among other details.

# %%
# !pip install Cinemagoer

# %%
import pandas as pd
from imdb import Cinemagoer
import json
import imdb

# %%
ia = Cinemagoer()

# %%
METADATA_DIR = "../../data/8_screenplays"

df = pd.read_csv(f'{METADATA_DIR}/1_validation/clean_validated.csv', dtype={'imdb_id': str, 'id_merged': str})

# %%
df.head()
# Out:
#    imdb_id             title  match  alt_id  \
# 0  0417385    12 and Holding      1     NaN
# 1  2024544  12 Years a Slave      1     NaN
# 2  1542344         127 Hours      1     NaN
# 3  0179626        15 Minutes      1     NaN
# 4  0974661          17 Again      1     NaN
#
#                                         script_url notes          filename  \
# 0    https://imsdb.com/scripts/12-and-Holding.html   NaN    12-and-Holding
# 1  https://imsdb.com/scripts/12-Years-a-Slave.html   NaN  12-Years-a-Slave
# 2         https://imsdb.com/scripts/127-Hours.html   NaN         127-Hours
# 3        https://imsdb.com/scripts/15-Minutes.html   NaN        15-Minutes
# 4          https://imsdb.com/scripts/17-Again.html   NaN          17-Again
#
#   id_merged                     char_fname
# 0   0417385    12-and-Holding_charinfo.txt
# 1   2024544  12-Years-a-Slave_charinfo.txt
# 2   1542344         127-Hours_charinfo.txt
# 3   0179626        15-Minutes_charinfo.txt
# 4   0974661          17-Again_charinfo.txt

# %%
df.shape
# Out:
# (1494, 9)

# %%
df['id_merged'].duplicated().sum()
# Out:
# 0

# %%
df['id_merged'].isnull().sum()
# Out:
# 0

# %%
all_data = []

# %%
def extract_info(imdb_id):
  m = ia.get_movie(imdb_id)

  res = {}

  for key in m.keys():
      info = m[key]
      if type(info) == list:
          for item in info:
              if not isinstance(item, str):
                  person_obj = {}
                  for person_key in item.keys():
                      person_obj[person_key] = item[person_key]
                  item = person_obj

              if res.get(key):
                  res[key].append(item)
              else:
                  res[key] = [item]
      else:
          res[key] = info
          # print(info, type(info))
          if not isinstance(info, imdb.Movie.Movie):
              res[key] = info
          else:
              res[key] = info.getID()

  all_data.append(res)
  return res

# %%
for index, row in df.iterrows():
  id = row['id_merged']
  response = extract_info(id)
  print(index, response['imdbID'])

# %%
import os

if not os.path.exists(f"{METADATA_DIR}/2_metadata"): os.mkdir(f"{METADATA_DIR}/2_metadata")

with open(f'{METADATA_DIR}/2_metadata/validated_meta.json', 'w') as f:
  json.dump(all_data, f)

# %% [markdown]
# Now, we also parse this info into a dataframe.

# %%
df = pd.read_json(f'{METADATA_DIR}/2_metadata/validated_meta.json', dtype={'imdbID': str})

# %%
df.head()
# Out:
#     localized title                                               cast  \
# 0    12 and Holding  [{'name': 'Conor Donovan', 'canonical name': '...
# 1  12 Years a Slave  [{'name': 'Chiwetel Ejiofor', 'canonical name'...
# 2         127 Hours  [{'name': 'James Franco', 'canonical name': 'F...
# 3        15 Minutes  [{'name': 'Robert De Niro', 'canonical name': ...
# 4          17 Again  [{'name': 'Zac Efron', 'canonical name': 'Efro...
#
#                                      genres runtimes  \
# 0                                   [Drama]     [95]
# 1               [Biography, Drama, History]    [134]
# 2                        [Biography, Drama]     [94]
# 3          [Action, Crime, Drama, Thriller]    [120]
# 4  [Comedy, Drama, Fantasy, Romance, Sport]    [102]
#
#                                  countries country codes  \
# 0                          [United States]          [us]
# 1          [United States, United Kingdom]      [us, gb]
# 2  [United States, United Kingdom, France]  [us, gb, fr]
# 3                 [United States, Germany]      [us, de]
# 4                          [United States]          [us]
#
#          language codes color info aspect ratio  \
# 0                  [en]    [Color]     1.85 : 1
# 1                  [en]    [Color]     2.35 : 1
# 2              [en, it]    [Color]     1.85 : 1
# 3  [en, cs, ru, el, af]    [Color]     2.35 : 1
# 4                  [en]    [Color]     2.35 : 1
#
#                                            sound mix  ... episode episode of  \
# 0                                    [Dolby Digital]  ...     NaN        NaN
# 1  [DTS::(Digital DTS Sound), Dolby Digital, SDDS...  ...     NaN        NaN
# 2                         [SDDS, Dolby Digital, DTS]  ...     NaN        NaN
# 3                         [DTS, Dolby Digital, SDDS]  ...     NaN        NaN
# 4                         [SDDS, Dolby Digital, DTS]  ...     NaN        NaN
#
#   long imdb episode title  series title  canonical series title episode title  \
# 0                     NaN           NaN                     NaN           NaN
# 1                     NaN           NaN                     NaN           NaN
# 2                     NaN           NaN                     NaN           NaN
# 3                     NaN           NaN                     NaN           NaN
# 4                     NaN           NaN                     NaN           NaN
#
#   canonical episode title smart canonical series title  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#   smart canonical episode title creator
# 0                           NaN     NaN
# 1                           NaN     NaN
# 2                           NaN     NaN
# 3                           NaN     NaN
# 4                           NaN     NaN
#
# [5 rows x 86 columns]

# %%
df[df['imdbID'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [localized title, cast, genres, runtimes, countries, country codes, language codes, color info, aspect ratio, sound mix, box office, certificates, original air date, rating, votes, cover url, imdbID, videos, languages, title, year, kind, original title, director, writer, producer, composer, cinematographer, editor, editorial department, casting director, production design, art direction, costume designer, make up, production manager, assistant director, art department, sound crew, special effects, stunt performer, camera and electrical department, casting department, costume department, location management, music department, script department, transportation department, miscellaneous crew, thanks, akas, production companies, distributors, special effects companies, other companies, plot, synopsis, canonical title, long imdb title, long imdb canonical title, smart canonical title, smart long imdb canonical title, full-size cover url, plot outline, set decoration, visual effects, top 250 rank, animation department, bottom 100 rank, series years, number of seasons, seasons, number of episodes, previous episode, next episode, season, episode, episode of, long imdb episode title, series title, canonical series title, episode title, canonical episode title, smart canonical series title, smart canonical episode title, creator]
# Index: []
#
# [0 rows x 86 columns]

# %%
df['kind'].value_counts()
# Out:
# kind
# movie          1456
# episode          17
# video movie       7
# tv series         7
# tv movie          5
# short             1
# Name: count, dtype: int64

# %%
df_clean = df[['movie' in kind for kind in df['kind']]]

# %%
df_clean.shape
# Out:
# (1468, 86)

# %%
df_clean.loc[df_clean['imdbID'] == '20768712']
# Out:
#                  localized title  \
# 545  Book Club: The Next Chapter
#
#                                                   cast    genres runtimes  \
# 545  [{'name': 'Diane Keaton', 'canonical name': 'K...  [Comedy]    [107]
#
#            countries country codes language codes color info aspect ratio  \
# 545  [United States]          [us]       [en, it]    [Color]     1.85 : 1
#
#     sound mix  ... episode episode of long imdb episode title  series title  \
# 545       NaN  ...     NaN        NaN                     NaN           NaN
#
#      canonical series title episode title canonical episode title  \
# 545                     NaN           NaN                     NaN
#
#     smart canonical series title smart canonical episode title creator
# 545                          NaN                           NaN     NaN
#
# [1 rows x 86 columns]

# %% [markdown]
# We export metadata for movies only into csv format.

# %%
df_clean.to_csv(f'{METADATA_DIR}/2_metadata/validated_movies.csv', index=False)
