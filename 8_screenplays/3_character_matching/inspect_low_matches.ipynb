# %% [markdown]
# ### Merge Match Data

# %% [markdown]
# This notebook merges the metadata with the matching data.

# %%
import pandas as pd
import os
import json
import re
import csv
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import matplotlib.gridspec as gridspec

# %%
METADATA_DIR = "../../data/8_screenplays"

df_meta = pd.read_csv(f'{METADATA_DIR}/1_validation/clean_validated.csv', dtype={'imdb_id': str, 'id_merged': str})

# %%
df_meta = df_meta.drop(['match', 'alt_id', 'notes'], axis=1)

# %%
df_meta.head()
# Out:
#    imdb_id             title                                       script_url  \
# 0  0417385    12 and Holding    https://imsdb.com/scripts/12-and-Holding.html
# 1  2024544  12 Years a Slave  https://imsdb.com/scripts/12-Years-a-Slave.html
# 2  1542344         127 Hours         https://imsdb.com/scripts/127-Hours.html
# 3  0179626        15 Minutes        https://imsdb.com/scripts/15-Minutes.html
# 4  0974661          17 Again          https://imsdb.com/scripts/17-Again.html
#
#            filename id_merged                     char_fname
# 0    12-and-Holding   0417385    12-and-Holding_charinfo.txt
# 1  12-Years-a-Slave   2024544  12-Years-a-Slave_charinfo.txt
# 2         127-Hours   1542344         127-Hours_charinfo.txt
# 3        15-Minutes   0179626        15-Minutes_charinfo.txt
# 4          17-Again   0974661          17-Again_charinfo.txt

# %% [markdown]
# Now, we'll look at the most recent subset of movies in our pipeline with "high coverage and matching"

# %%
df_stats = pd.read_csv(f'{METADATA_DIR}/3_character_matching/movies_with_high_coverage_and_matching/imdb_and_stats.csv', dtype={'imdb': str})

# %%
df_stats.head()
# Out:
#       imdb  high_matches  avg_score  coverage
# 0  0021214      0.545455  70.818182  0.972222
# 1  0022054      0.521739  71.478261  0.959559
# 2  0022958      0.750000  86.944444  0.977011
# 3  0024216      0.514286  74.514286  0.970219
# 4  0025878      0.714286  82.632653  0.977593

# %%
df_stats.shape
# Out:
# (1367, 4)

# %%
stats_meta = df_stats.merge(df_meta, left_on='imdb', right_on='id_merged').drop(['id_merged', 'imdb_id'], axis=1)

# %%
stats_meta.head()
# Out:
#       imdb  high_matches  avg_score  coverage                          title  \
# 0  0021214      0.545455  70.818182  0.972222                  One Good Turn
# 1  0022054      0.521739  71.478261  0.959559  The Last Flight of Noah's Ark
# 2  0022958      0.750000  86.944444  0.977011       The Grand Budapest Hotel
# 3  0024216      0.514286  74.514286  0.970219                      King Kong
# 4  0025878      0.714286  82.632653  0.977593                   The Thin Man
#
#                                           script_url          filename  \
# 0                 https://sfy.ru/?script=onegoodturn     One-Good-Turn
# 1  https://imsdb.com/scripts/Last-Flight%2C-The.html   Last-Flight-The
# 2            https://sfy.ru/?script=grand_hotel_1932       Grand-Hotel
# 3  https://www.dailyscript.com/scripts/kong1933.html  Kong-(King-Kong)
# 4  https://www.dailyscript.com/scripts/thethinman...      The-Thin-Man
#
#                       char_fname
# 0     One-Good-Turn_charinfo.txt
# 1   Last-Flight-The_charinfo.txt
# 2       Grand-Hotel_charinfo.txt
# 3  Kong-(King-Kong)_charinfo.txt
# 4      The-Thin-Man_charinfo.txt

# %%
stats_meta.shape
# Out:
# (1366, 8)

# %%
stats_meta[stats_meta['high_matches'] > 0.8]
# Out:
#          imdb  high_matches  avg_score  coverage                  title  \
# 8     0031725      0.967742  92.322581  0.987118              Ninotchka
# 11    0032551      0.919355  92.887097  0.971596    The Grapes of Wrath
# 19    0036104      0.857143  87.942857  0.958199        The Leopard Man
# 22    0036613      0.900000  89.100000  0.996859   Arsenic and Old Lace
# 24    0036775      0.954545  89.863636  0.992388       Double Indemnity
# ...       ...           ...        ...       ...                    ...
# 1356  8579674      0.971429  97.057143  0.952224                   1917
# 1358  8722346      0.846154  92.384615  0.989796           Queen & Slim
# 1360  8946378      0.913043  89.869565  0.943590             Knives Out
# 1361  9620292      0.888889  95.296296  0.972749  Promising Young Woman
# 1364  9777644      0.894737  94.894737  0.954304            Da 5 Bloods
#
#                                              script_url  \
# 8              https://imsdb.com/scripts/Ninotchka.html
# 11    https://imsdb.com/scripts/Grapes-of-Wrath%2C-T...
# 19                   https://sfy.ru/?script=leopard_man
# 22    https://imsdb.com/scripts/Arsenic-and-Old-Lace...
# 24         https://sfy.ru/?script=double_indemnity_1944
# ...                                                 ...
# 1356  https://script-pdf.s3-us-west-2.amazonaws.com/...
# 1358  https://script-pdf.s3-us-west-2.amazonaws.com/...
# 1360  https://script-pdf.s3-us-west-2.amazonaws.com/...
# 1361  https://script-pdf.s3-us-west-2.amazonaws.com/...
# 1364  https://script-pdf.s3-us-west-2.amazonaws.com/...
#
#                    filename                          char_fname
# 8                 Ninotchka              Ninotchka_charinfo.txt
# 11      Grapes-of-Wrath-The    Grapes-of-Wrath-The_charinfo.txt
# 19          Leopard-Man-The        Leopard-Man-The_charinfo.txt
# 22     Arsenic-and-Old-Lace   Arsenic-and-Old-Lace_charinfo.txt
# 24         Double-Indemnity       Double-Indemnity_charinfo.txt
# ...                     ...                                 ...
# 1356                   1917                   1917_charinfo.txt
# 1358         Queen-and-Slim         Queen-and-Slim_charinfo.txt
# 1360             Knives-Out             Knives-Out_charinfo.txt
# 1361  Promising-Young-Woman  Promising-Young-Woman_charinfo.txt
# 1364            Da-5-Bloods            Da-5-Bloods_charinfo.txt
#
# [546 rows x 8 columns]

# %%
stats_meta.to_csv(f'{METADATA_DIR}/3_character_matching/movies_with_high_coverage_and_matching/meta_imdb_and_stats.csv', index=False)
