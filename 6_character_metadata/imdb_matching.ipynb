# %%
# !pip install cinemagoer

# %%
from imdb import Cinemagoer
import pandas as pd

# %%
import os
import sys
sys.path.append("../")

from consts import CLEAN_SCRAPE_DIR, BEFORE_2010_DIR, IN_2010S, AFTER_2020

# %%
ia = Cinemagoer()

# %%
all_movies = pd.read_csv("all_people_with_duplicates.csv")['movie'].unique()

# %%
len(all_movies)
# Out:
# 3557

# %%
dfs = []

for DIR in [CLEAN_SCRAPE_DIR, BEFORE_2010_DIR, IN_2010S, AFTER_2020]:
    TARGET_DIR = f"../4_parse_xrays/parsed_xrays/{DIR}_sub_movies_with_xrays.csv"
    df_temp = pd.read_csv(TARGET_DIR)
    df_temp['dir'] = DIR

    dfs.append(df_temp)

# %%
df_all = pd.concat(dfs)

# %%
df_all.shape
# Out:
# (3576, 12)

# %%
df_all.head()
# Out:
#                                    file                             title  \
# 0                            0_My_Fault                          My Fault
# 1    1000_On_The_Trail_of_UFOS_Dark_Sky    On The Trail of UFOS: Dark Sky
# 2              1001_Student_Of_The_Year               Student Of The Year
# 3  1005_The_Badge_The_Bible_and_Bigfoot  The Badge, The Bible and Bigfoot
# 4      1009_Sharknado_5_Global_Swarming      Sharknado 5: Global Swarming
#
#   entityType  runtimeSeconds  \
# 0      Movie          7056.0
# 1      Movie          5123.0
# 2      Movie          8722.0
# 3      Movie          3971.0
# 4      Movie          5159.0
#
#                                             synopsis  rating_count  rating  \
# 0  Noah must leave her town, boyfriend and friend...         817.0     4.7
# 1  On the Trail of UFOs: Dark Sky traces decades ...         408.0     3.7
# 2  Introducing Alia Bhatt (Sharanya Singhania), S...          60.0     3.7
# ...

# %%
df_all[~df_all['file'].isin(all_movies)]
# Out:
#                                                    file  \
# 295                         1542_Volcanic_UFO_Mysteries
# 484                       184_Lucys_Really_Lost_Moments
# 852      255_Prisoner_Number_A26188_Surviving_Auschwitz
# 1119                            3178_Prescription_Thugs
# 1305                    3574_Borat_Subsequent_Moviefilm
# 1306  3575_Baby_Shark__More_Kids_Songs__Super_Simple...
# 1455                                        3967_Rustum
# 1740                                   4825_Janamaithri
# 1950                         5383_Pnk_All_I_Know_So_Far
# 1965              5402_The_Haunting_of_Patricia_Johnson
# 2161  5641_Queen__The_Making_Of_A_Night_At_The_Opera...
# 2382            5967_Jennifer_Aniston_More_than_Friends
# 2477                       6097_Chitty_Chitty_Bang_Bang
# 2543     6200_Kendrick_Lamar_Live_The_Big_Steppers_Tour
# 3     1085_The_Making_Of_A_Night_At_The_Opera_Classi...
# 39                                        1398_Bharaate
# ...
