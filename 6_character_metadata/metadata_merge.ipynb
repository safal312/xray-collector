# %% [markdown]
# ### Metadata Merge

# %% [markdown]
# This notebook merges current metadata collected from Playback resources with metadata collected from `2_parse_links` to get all necessary details. It removes all the columns that are not necessary for a high level overview of the movie.

# %%
import pandas as pd

# %%
METADATA_DIR = "../data/6_character_metadata"
df = pd.read_csv(f"{METADATA_DIR}/movies_with_ids.csv", dtype={'movie_id': str})

# %%
print(df.shape)
print(df.columns)
# Out:
# (3567, 15)
# Index(['file', 'title', 'entityType', 'runtimeSeconds', 'synopsis',
#        'rating_count', 'rating', 'en_type', 'en_url', 'sdh_sub_lang', 'url',
#        'dir', 'movie_id', 'match_error', 'cast_num'],
#       dtype='object')

# %%
df_ids = df.loc[:, ['title', 'movie_id',  'file', 'dir', 'synopsis']]

# %%
df_ids
# Out:
#                                  title  movie_id  \
# 0                             My Fault  21909764
# 1       On The Trail of UFOS: Dark Sky  14928972
# 2                  Student Of The Year   2172071
# 3     The Badge, The Bible and Bigfoot  11208026
# 4         Sharknado 5: Global Swarming   6298780
# ...                                ...       ...
# 3562                   Lucifer (Tamil)       NaN
# 3563              A Place at the Table   1736049
# 3564             Go Straight Take Left   8956392
# 3565                   It Never Sleeps       NaN
# 3566                  True Grit (1969)   0065126
#
#                                       file      dir  \
# 0                               0_My_Fault      com
# 1       1000_On_The_Trail_of_UFOS_Dark_Sky      com
# 2                 1001_Student_Of_The_Year      com
# 3     1005_The_Badge_The_Bible_and_Bigfoot      com
# 4         1009_Sharknado_5_Global_Swarming      com
# ...                                    ...      ...
# 3562                    1299_Lucifer_Tamil  in2010s
# 3563             1598_A_Place_at_the_Table  in2010s
# 3564            2411_Go_Straight_Take_Left  in2010s
# 3565                  2580_It_Never_Sleeps      com
# 3566                   5659_True_Grit_1969      com
#
#                                                synopsis
# 0     Noah must leave her town, boyfriend and friend...
# 1     On the Trail of UFOs: Dark Sky traces decades ...
# 2     Introducing Alia Bhatt (Sharanya Singhania), S...
# 3     In a small coastal town Bigfoot is sighted, an...
# 4     With much of North America lying in ruins, the...
# ...                                                 ...
# 3562                                                NaN
# 3563                                                NaN
# 3564                                                NaN
# 3565                                                NaN
# 3566                                                NaN
#
# [3567 rows x 5 columns]

# %%
PARSE_LINKS_DIR = "../data/2_metadata"
df_com = pd.read_csv(f"{PARSE_LINKS_DIR}/com/clean_meta_en_prime.csv")
df_before2010 = pd.read_csv(f"{PARSE_LINKS_DIR}/before2010/clean_meta_en_prime.csv")
df_in2010 = pd.read_csv(f"{PARSE_LINKS_DIR}/in2010s/clean_meta_en_prime.csv")
df_after2020 = pd.read_csv(f"{PARSE_LINKS_DIR}/after2020/clean_meta_en_prime.csv")

# %%
df_com.columns
# Out:
# Index(['title', 'link', 'tags', 'year', 'clean_title', 'fname', 'short_url',
#        'clean_short_url'],
#       dtype='object')

# %%
dfs = [df_com, df_before2010, df_in2010, df_after2020]
df_temp = df_ids
df_temp[['year', 'link']] = None

for _df in dfs:
    df_ids_merged_f = df_temp.merge(_df[['fname', 'year', 'link']], how='left', left_on='file', right_on='fname', suffixes=('', '_x')).drop('fname', axis=1)
    df_ids_merged_f['year'] = df_ids_merged_f['year'].combine_first(df_ids_merged_f['year_x'])
    df_ids_merged_f['link'] = df_ids_merged_f['link'].combine_first(df_ids_merged_f['link_x'])
    df_temp = df_ids_merged_f.drop(['year_x', 'link_x'], axis=1)
    print(df_temp['year'].isnull().sum(), df_temp['link'].isnull().sum())

df_temp
# Out:
# 683 683
# 551 551
# 295 295
# 5 5
#                                  title  movie_id  \
# 0                             My Fault  21909764
# 1       On The Trail of UFOS: Dark Sky  14928972
# 2                  Student Of The Year   2172071
# 3     The Badge, The Bible and Bigfoot  11208026
# 4         Sharknado 5: Global Swarming   6298780
# ...                                ...       ...
# 3562                   Lucifer (Tamil)       NaN
# 3563              A Place at the Table   1736049
# 3564             Go Straight Take Left   8956392
# 3565                   It Never Sleeps       NaN
# 3566                  True Grit (1969)   0065126
#
#                                       file      dir  \
# 0                               0_My_Fault      com
# 1       1000_On_The_Trail_of_UFOS_Dark_Sky      com
# 2                 1001_Student_Of_The_Year      com
# 3     1005_The_Badge_The_Bible_and_Bigfoot      com
# 4         1009_Sharknado_5_Global_Swarming      com
# ...                                    ...      ...
# 3562                    1299_Lucifer_Tamil  in2010s
# 3563             1598_A_Place_at_the_Table  in2010s
# 3564            2411_Go_Straight_Take_Left  in2010s
# 3565                  2580_It_Never_Sleeps      com
# 3566                   5659_True_Grit_1969      com
#
#                                                synopsis    year  \
# 0     Noah must leave her town, boyfriend and friend...  2023.0
# 1     On the Trail of UFOs: Dark Sky traces decades ...  2021.0
# 2     Introducing Alia Bhatt (Sharanya Singhania), S...  2012.0
# 3     In a small coastal town Bigfoot is sighted, an...  2019.0
# 4     With much of North America lying in ruins, the...  2017.0
# ...                                                 ...     ...
# 3562                                                NaN  2019.0
# 3563                                                NaN  2013.0
# 3564                                                NaN  2018.0
# 3565                                                NaN  2021.0
# 3566                                                NaN  1969.0
#
#                                                    link
# 0     /My-Fault-Nicole-Wallace/dp/B0B683GB78/ref=sr_...
# 1     /Trail-UFOS-Dark-Sky/dp/B09BKF2WGQ/ref=sr_1_24...
# 2     /Student-Year-Sidharth-Malhotra/dp/B0BZTD87WK/...
# 3     /Badge-Bible-Bigfoot-Ashley-Wright/dp/B09JMYV8...
# 4     /Sharknado-Global-Swarming-Ian-Ziering/dp/B07M...
# ...                                                 ...
# 3562  /Lucifer-Tamil-Mohanlal/dp/B08KWR2Q2G/ref=sr_1...
# 3563  /Place-at-Table-Jeff-Bridges/dp/B00BN506KU/ref...
# 3564  /Straight-Take-Left-Naveen-Richard/dp/B07HDC11...
# 3565  /Never-Sleeps-Laura-Swift/dp/B096HXDD4J/ref=sr...
# 3566  /True-Grit-John-Wayne/dp/B000ID1VYS/ref=sr_1_9...
#
# [3567 rows x 7 columns]

# %%
df_temp['movie_id'].isnull().sum()
# Out:
# 441

# %%
df_temp.to_csv(f"{METADATA_DIR}/metadata_for_validation.csv", index=False)
